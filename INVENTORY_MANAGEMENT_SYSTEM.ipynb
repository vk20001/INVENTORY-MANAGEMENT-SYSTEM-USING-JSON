# %%
products={ 180600200 :{"product_name":"Yogurt ", "product_price": 45 , "product_Count": 500 ,"product_weight":100 , "product_carbhohydrate_content": 34 ,"product_calorie_content": 220 },
        180600201:{"product_name":"Pudding", "product_price": 90 , "product_Count": 673, "product_weight": 50 , "product_carbhohydrate_content": 30 ,"product_calorie_content": 161 },
        180600202:{"product_name":"Apple juice", "product_price": 135 , "product_Count": 782, "product_weight":500 , "product_carbhohydrate_content": 28 ,"product_calorie_content": 111 },
        180600203:{"product_name":"Dates", "product_price": 299 , "product_Count": 450, "product_weight":500 , "product_carbhohydrate_content": 61 ,"product_calorie_content": 228 },
        180600204:{"product_name":"Raspberries", "product_price": 599 , "product_Count": 830, "product_weight":250 , "product_carbhohydrate_content": 14,"product_calorie_content":61 },
        180600205:{"product_name":"Strawberries", "product_price": 299 , "product_Count": 560, "product_weight":500 , "product_carbhohydrate_content": 11 ,"product_calorie_content":45 },
        180600206:{"product_name":"Prunes ", "product_price": 200, "product_Count":347, "product_weight":200 , "product_carbhohydrate_content":53 ,"product_calorie_content":201 },
        180600207:{"product_name":"Bagel ", "product_price":200 , "product_Count":564, "product_weight":250 , "product_carbhohydrate_content":31 ,"product_calorie_content":165 },
        180600208:{"product_name":"Breadsticks ", "product_price":50 , "product_Count":456, "product_weight":100 ,  "product_carbhohydrate_content":15 ,"product_calorie_content":77 },
        180600209:{"product_name":"Bread", "product_price":30 , "product_Count":200 ,"product_weight":250 , "product_carbhohydrate_content":11,"product_calorie_content":55 },
        180600210:{"product_name":"Graham crackers", "product_price":450, "product_Count":765, "product_weight":1 , "product_carbhohydrate_content":11 ,"product_calorie_content":60 },
        180600211:{"product_name":"Muffin", "product_price":40 , "product_Count":800, "product_weight":100, "product_carbhohydrate_content":25 ,"product_calorie_content":130 },
        180600212:{"product_name":"Fig Bar", "product_price":340 , "product_Count": 780, "product_weight":200 , "product_carbhohydrate_content":10 ,"product_calorie_content":50 },
        180600213:{"product_name":"Granola bar ", "product_price":300 , "product_Count":890, "product_weight":200 , "product_carbhohydrate_content":19 ,"product_calorie_content":125 },
        180600214:{"product_name":"Hamburger bun", "product_price":110 , "product_Count":500, "product_weight":250 , "product_carbhohydrate_content":21 ,"product_calorie_content":119 },
        180600215:{"product_name":"Hot dog bun ", "product_price":80, "product_Count":678, "product_weight":300 , "product_carbhohydrate_content":21 ,"product_calorie_content":119 },
        180600216:{"product_name":"Oatmeal", "product_price":170 , "product_Count":890, "product_weight":1 , "product_carbhohydrate_content":12 ,"product_calorie_content":66 },
        180600217:{"product_name":"Pancake mix ", "product_price":164 , "product_Count":560, "product_weight":200, "product_carbhohydrate_content":10 ,"product_calorie_content":41 },
        180600218:{"product_name":"Popcorn", "product_price": 50, "product_Count":450, "product_weight":30 , "product_carbhohydrate_content":6 ,"product_calorie_content": 26},
        180600219:{"product_name":"Tortilla,", "product_price":130 , "product_Count": 765, "product_weight":348 , "product_carbhohydrate_content":15 ,"product_calorie_content":85 },
        180600220:{"product_name":"Waffles ", "product_price": 300 , "product_Count":279, "product_weight":200 , "product_carbhohydrate_content":17 ,"product_calorie_content":130 },
        180600221:{"product_name":"Noodles (spaghetti)", "product_price":101 , "product_Count": 786, "product_weight":85 , "product_carbhohydrate_content":34 ,"product_calorie_content":159 },
        180600222:{"product_name":"White beans", "product_price":30 , "product_Count":560, "product_weight":200 , "product_carbhohydrate_content":23 ,"product_calorie_content":189 },
        180600223:{"product_name":"Garbanzo beans", "product_price":35 , "product_Count": 458, "product_weight":150, "product_carbhohydrate_content":45 ,"product_calorie_content":249 },
        180600224:{"product_name":"Black eyed peas ", "product_price":75 , "product_Count":576, "product_weight":1 , "product_carbhohydrate_content":22 ,"product_calorie_content":134 },
        180600225:{"product_name":"Orange Juice", "product_price":71 , "product_Count":590, "product_weight":250 , "product_carbhohydrate_content":26 ,"product_calorie_content":112 },
        180600226:{"product_name":"Grape Juice", "product_price":77 , "product_Count":650, "product_weight":200 , "product_carbhohydrate_content":23 ,"product_calorie_content":96 },
        180600227:{"product_name":"Sweet Potato", "product_price":55, "product_Count":456, "product_weight":200 , "product_carbhohydrate_content":28 ,"product_calorie_content": 118},
        180600228:{"product_name":"Cornflakes", "product_price":310, "product_Count":789, "product_weight":1 , "product_carbhohydrate_content": 50,"product_calorie_content":130 },
        180600229:{"product_name":"Muesli", "product_price":299 , "product_Count":765, "product_weight":400 , "product_carbhohydrate_content":34 ,"product_calorie_content":195 },
        180600230:{"product_name":"Pasta", "product_price":162, "product_Count":567, "product_weight":500 , "product_carbhohydrate_content":22 ,"product_calorie_content":390 },
        180600231:{"product_name":"Vanilla Essence", "product_price":50 , "product_Count":678, "product_weight":20 , "product_carbhohydrate_content":18 ,"product_calorie_content":288 },
        180600232:{"product_name":"Custard Powder", "product_price":37 , "product_Count":564, "product_weight":100 , "product_carbhohydrate_content":20 ,"product_calorie_content":348 },
        180600233:{"product_name":"Milkmaid", "product_price":128 , "product_Count":768, "product_weight":100 , "product_carbhohydrate_content":28 ,"product_calorie_content":322 },
        180600234:{"product_name":"Cream Cheese", "product_price":385 , "product_Count":876, "product_weight":200 , "product_carbhohydrate_content":32 ,"product_calorie_content":342 },
        180600235:{"product_name":"Cottage Cheese", "product_price":85 , "product_Count":842, "product_weight":150 , "product_carbhohydrate_content":35 ,"product_calorie_content":156 },
}

# %%
products
# Out:
# {180600200: {'product_Count': 500,
#   'product_calorie_content': 220,
#   'product_carbhohydrate_content': 34,
#   'product_name': 'Yogurt ',
#   'product_price': 45,
#   'product_weight': 100},
#  180600201: {'product_Count': 673,
#   'product_calorie_content': 161,
#   'product_carbhohydrate_content': 30,
#   'product_name': 'Pudding',
#   'product_price': 90,
#   'product_weight': 50},
#  180600202: {'product_Count': 782,
#   'product_calorie_content': 111,
#   'product_carbhohydrate_content': 28,
#   'product_name': 'Apple juice',
#   'product_price': 135,
#   'product_weight': 500},
#  180600203: {'product_Count': 450,
#   'product_calorie_content': 228,
#   'product_carbhohydrate_content': 61,
#   'product_name': 'Dates',
#   'product_price': 299,
#   'product_weight': 500},
#  180600204: {'product_Count': 830,
#   'product_calorie_content': 61,
#   'product_carbhohydrate_content': 14,
#   'product_name': 'Raspberries',
#   'product_price': 599,
#   'product_weight': 250},
# ...

# %% [markdown]
# **READ INVENTORY**

# %%
import json
data=json.dumps(products)
data
# Out:
# '{"180600200": {"product_name": "Yogurt ", "product_price": 45, "product_Count": 500, "product_weight": 100, "product_carbhohydrate_content": 34, "product_calorie_content": 220}, "180600201": {"product_name": "Pudding", "product_price": 90, "product_Count": 673, "product_weight": 50, "product_carbhohydrate_content": 30, "product_calorie_content": 161}, "180600202": {"product_name": "Apple juice", "product_price": 135, "product_Count": 782, "product_weight": 500, "product_carbhohydrate_content": 28, "product_calorie_content": 111}, "180600203": {"product_name": "Dates", "product_price": 299, "product_Count": 450, "product_weight": 500, "product_carbhohydrate_content": 61, "product_calorie_content": 228}, "180600204": {"product_name": "Raspberries", "product_price": 599, "product_Count": 830, "product_weight": 250, "product_carbhohydrate_content": 14, "product_calorie_content": 61}, "180600205": {"product_name": "Strawberries", "product_price": 299, "product_Count": 560, "product_weigh
# ...

# %%
fd = open("data.json", 'w')

fd.write(data)

fd.close()

# %%
fd = open("data.json", 'r')

txt=fd.read()

fd.close()

# %%
data=json.loads(txt)
data
# Out:
# {'180600200': {'product_Count': 500,
#   'product_calorie_content': 220,
#   'product_carbhohydrate_content': 34,
#   'product_name': 'Yogurt ',
#   'product_price': 45,
#   'product_weight': 100},
#  '180600201': {'product_Count': 673,
#   'product_calorie_content': 161,
#   'product_carbhohydrate_content': 30,
#   'product_name': 'Pudding',
#   'product_price': 90,
#   'product_weight': 50},
#  '180600202': {'product_Count': 782,
#   'product_calorie_content': 111,
#   'product_carbhohydrate_content': 28,
#   'product_name': 'Apple juice',
#   'product_price': 135,
#   'product_weight': 500},
#  '180600203': {'product_Count': 450,
#   'product_calorie_content': 228,
#   'product_carbhohydrate_content': 61,
#   'product_name': 'Dates',
#   'product_price': 299,
#   'product_weight': 500},
#  '180600204': {'product_Count': 830,
#   'product_calorie_content': 61,
#   'product_carbhohydrate_content': 14,
#   'product_name': 'Raspberries',
#   'product_price': 599,
# ...

# %% [markdown]
# **ADDING NEW ITEMS INTO INVENTORY**

# %%
product_id = str(input("Enter product id:"))
product_name = str(input("Enter name:"))
product_price = int(input("Enter price:"))
product_count = int(input("Enter quantity:"))
product_weight = int(input("Enter product weight:"))
product_carbhohydrate_content = int(input("Enter carbhohydrate content:"))
product_calorie_content = int(input("Enter calorie content:"))

data[product_id] = {'product_name':product_name, 'product_price':product_price, 'product_count':product_count, 'product_weight':product_weight,'product_carbhohydrate_content':product_carbhohydrate_content, 'product_calorie_content':product_calorie_content}

js = json.dumps(data)

fd = open("data.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter product id:180600237
# Enter name:Cheese Spread
# Enter price:200
# Enter quantity:450
# Enter product weight:100
# Enter carbhohydrate content:12
# Enter calorie content:145

# %%
data
# Out:
# {'180600200': {'product_Count': 500,
#   'product_calorie_content': 220,
#   'product_carbhohydrate_content': 34,
#   'product_name': 'Yogurt ',
#   'product_price': 45,
#   'product_weight': 100},
#  '180600201': {'product_Count': 673,
#   'product_calorie_content': 161,
#   'product_carbhohydrate_content': 30,
#   'product_name': 'Pudding',
#   'product_price': 90,
#   'product_weight': 50},
#  '180600202': {'product_Count': 782,
#   'product_calorie_content': 111,
#   'product_carbhohydrate_content': 28,
#   'product_name': 'Apple juice',
#   'product_price': 135,
#   'product_weight': 500},
#  '180600203': {'product_Count': 450,
#   'product_calorie_content': 228,
#   'product_carbhohydrate_content': 61,
#   'product_name': 'Dates',
#   'product_price': 299,
#   'product_weight': 500},
#  '180600204': {'product_Count': 830,
#   'product_calorie_content': 61,
#   'product_carbhohydrate_content': 14,
#   'product_name': 'Raspberries',
#   'product_price': 599,
# ...

# %% [markdown]
# **PURCHASING PRODUCTS**

# %%
print('''
-------------------------------------

Welcome to Allen's Grocery Store

-------------------------------------
''')
# Out:
# -------------------------------------
#
# Welcome to Allen's Grocery Store
#
# -------------------------------------

# %%
ui_product = str(input("Enter product ID of item that you'd like to buy: "))

print("************************************************")
print("Product's name:", data[ui_product]["product_name"])
print("Price:", data[ui_product]["product_price"])
print("Net Weight(kg/g/ml/l):", data[ui_product]["product_weight"])

print("************************************************")
print("\n")
print("-------------------Great choice of product!!-----------------------")
print("\n")

ui_quantity = int(input("Enter the quantity: "))
ui_discount = int(input("Enter the coupon code(if you have any): "))

print("Billing Amount:",data[ui_product]["product_price"]* ui_quantity - ui_discount/100)

print("--------------------------------------------")
print("Thanks for Purchasing, Have a Nice Day!!!!!")
print("--------------------------------------------")
# Out:
# Enter product ID of item that you'd like to buy: 180600205
# ************************************************
# Product's name: Strawberries
# Price: 299
# Net Weight(kg/g/ml/l): 500
# ************************************************
#
#
# -------------------Great choice of product!!-----------------------
#
#
# Enter the quantity: 6
# Enter the coupon code(if you have any): 20
# Billing Amount: 1793.8
# --------------------------------------------
# Thanks for Purchasing, Have a Nice Day!!!!!
# --------------------------------------------

# %% [markdown]
# **UPDATING INVENTORY AFTER PURCHASE**

# %%
data[ui_product]['product_Count'] = data[ui_product]['product_Count'] - ui_quantity

js = json.dumps(data)

fd = open("data.json",'w')
fd.write(js)
fd.close()

# %% [markdown]
# **SALES**

# %%
{'prod' : ui_product, 'product_Count' : ui_quantity, 'amount': data[ui_product]['product_price'] * ui_quantity - ui_discount/100}
# Out:
# {'amount': 1793.8, 'prod': '180600205', 'product_Count': 6}

# %%
sales = {1:{'prod' : ui_product, 'product_Count' : ui_quantity, 'amount': data[ui_product]['product_price'] * ui_quantity - ui_discount/100}  }

# %%
sales[(len(sales) + 1)] = {'prod' : ui_product, 'product_Count' : ui_quantity, 'amount': data[ui_product]['product_price'] * ui_quantity - ui_discount/100}

# %%
s= json.dumps(sales)

# %%
sales
# Out:
# {1: {'amount': 600.0, 'prod': '180600220', 'product_Count': 2},
#  2: {'amount': 600.0, 'prod': '180600220', 'product_Count': 2},
#  3: {'amount': 100.0, 'prod': '180600231', 'product_Count': 2},
#  4: {'amount': 1020.0, 'prod': '180600212', 'product_Count': 3},
#  5: {'amount': 424.5, 'prod': '180600235', 'product_Count': 5},
#  6: {'amount': 180.0, 'prod': '180600200', 'product_Count': 4},
#  7: {'amount': 1793.8, 'prod': '180600205', 'product_Count': 6}}

# %%
fd = open("sales.json",'w')
fd.write(s)
fd.close()
